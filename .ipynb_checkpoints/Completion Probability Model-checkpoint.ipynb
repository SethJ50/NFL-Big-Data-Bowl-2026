# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, accuracy_score, log_loss
from sklearn.model_selection import train_test_split
import joblib

# %%
# Load datasets
train_df = pd.read_csv("train_dataset.csv")
val_df = pd.read_csv("val_dataset.csv")

# %%
# Label
target = 'complete'

# Features (all columns in your CSV except target and IDs)
id_cols = ['game_id', 'play_id']
feature_cols = [c for c in train_df.columns if c not in [target] + id_cols]

X_train = train_df[feature_cols]
y_train = train_df[target]

X_val = val_df[feature_cols]
y_val = val_df[target]

for col in ['route_group', 'route_of_targeted_receiver']:
    X_train[col] = X_train[col].astype('category').cat.codes
    X_val[col] = X_val[col].astype('category').cat.codes
# Out:
# /var/folders/55/cmm1r3h92wl2408nd3911m2c0000gn/T/ipykernel_56006/1613854857.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[col] = X_train[col].astype('category').cat.codes
# /var/folders/55/cmm1r3h92wl2408nd3911m2c0000gn/T/ipykernel_56006/1613854857.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_val[col] = X_val[col].astype('category').cat.codes
# /var/folders/55/cmm1r3h92wl2408nd3911m2c0000gn/T/ipykernel_56006/1613854857.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[col] = X_train[col].astype('category').cat.codes
# /var/folders/55/cmm1r3h92wl2408nd3911m2c0000gn/T/ipykernel_56006/1613854857.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_val[col] = X_val[col].astype('category').cat.codes

# %%
# XGBoost classifier for probability output
xgb_model = XGBClassifier(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    use_label_encoder=False,
    eval_metric='logloss',
    enable_categorical=True,
    random_state=42
)

# Fit the model
xgb_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=True)
# Out:
# [0]	validation_0-logloss:0.65416
# [1]	validation_0-logloss:0.64642
# [2]	validation_0-logloss:0.63970
# [3]	validation_0-logloss:0.63404
# [4]	validation_0-logloss:0.62765
# [5]	validation_0-logloss:0.62193
# [6]	validation_0-logloss:0.61645
# [7]	validation_0-logloss:0.61153
# [8]	validation_0-logloss:0.60726
# [9]	validation_0-logloss:0.60360
# [10]	validation_0-logloss:0.60003
# [11]	validation_0-logloss:0.59636
# [12]	validation_0-logloss:0.59454
# [13]	validation_0-logloss:0.59139
# [14]	validation_0-logloss:0.58854
# [15]	validation_0-logloss:0.58647
# [16]	validation_0-logloss:0.58444
# [17]	validation_0-logloss:0.58343
# [18]	validation_0-logloss:0.58156
# [19]	validation_0-logloss:0.58050
# [20]	validation_0-logloss:0.57873
# [21]	validation_0-logloss:0.57756
# [22]	validation_0-logloss:0.57649
# [23]	validation_0-logloss:0.57448
# [24]	validation_0-logloss:0.57334
# [25]	validation_0-logloss:0.57151
# [26]	validation_0-logloss:0.56963
# [27]	validation_0-logloss:0.56790
# [28]	validation_0-logloss:0.56661
# [29]	validation_0-logloss:0.56585
# [30]	validation_0-logloss:0.56483
# [31]	validation_0-logloss:0.56393
# [32]	validation_0-logloss:0.56253
# [33]	validation_0-logloss:0.56176
# [34]	validation_0-logloss:0.56011
# [35]	validation_0-logloss:0.55909
# [36]	validation_0-logloss:0.55897
# [37]	validation_0-logloss:0.55768
# [38]	validation_0-logloss:0.55697
# [39]	validation_0-logloss:0.55536
# [40]	validation_0-logloss:0.55423
# [41]	validation_0-logloss:0.55380
# [42]	validation_0-logloss:0.55312
# [43]	validation_0-logloss:0.55197
# [44]	validation_0-logloss:0.55178
# [45]	validation_0-logloss:0.55119
# [46]	validation_0-logloss:0.55042
# [47]	validation_0-logloss:0.54862
# [48]	validation_0-logloss:0.54838
# [49]	validation_0-logloss:0.54778
# [50]	validation_0-logloss:0.54699
# [51]	validation_0-logloss:0.54686
# [52]	validation_0-logloss:0.54690
# [53]	validation_0-logloss:0.54570
# [54]	validation_0-logloss:0.54565
# [55]	validation_0-logloss:0.54570
# [56]	validation_0-logloss:0.54419
# [57]	validation_0-logloss:0.54494
# [58]	validation_0-logloss:0.54370
# [59]	validation_0-logloss:0.54243
# [60]	validation_0-logloss:0.54295
# [61]	validation_0-logloss:0.54275
# [62]	validation_0-logloss:0.54301
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [17:21:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [63]	validation_0-logloss:0.54275
# [64]	validation_0-logloss:0.54319
# [65]	validation_0-logloss:0.54392
# [66]	validation_0-logloss:0.54381
# [67]	validation_0-logloss:0.54376
# [68]	validation_0-logloss:0.54381
# [69]	validation_0-logloss:0.54347
# [70]	validation_0-logloss:0.54275
# [71]	validation_0-logloss:0.54179
# [72]	validation_0-logloss:0.54091
# [73]	validation_0-logloss:0.54105
# [74]	validation_0-logloss:0.54115
# [75]	validation_0-logloss:0.54067
# [76]	validation_0-logloss:0.54055
# [77]	validation_0-logloss:0.54045
# [78]	validation_0-logloss:0.54006
# [79]	validation_0-logloss:0.53991
# [80]	validation_0-logloss:0.53910
# [81]	validation_0-logloss:0.53911
# [82]	validation_0-logloss:0.53901
# [83]	validation_0-logloss:0.53830
# [84]	validation_0-logloss:0.53821
# [85]	validation_0-logloss:0.53799
# [86]	validation_0-logloss:0.53704
# [87]	validation_0-logloss:0.53744
# [88]	validation_0-logloss:0.53850
# [89]	validation_0-logloss:0.53967
# [90]	validation_0-logloss:0.53962
# [91]	validation_0-logloss:0.53946
# [92]	validation_0-logloss:0.53853
# [93]	validation_0-logloss:0.53858
# [94]	validation_0-logloss:0.53808
# [95]	validation_0-logloss:0.53789
# [96]	validation_0-logloss:0.53755
# [97]	validation_0-logloss:0.53780
# [98]	validation_0-logloss:0.53805
# [99]	validation_0-logloss:0.53762
# [100]	validation_0-logloss:0.53759
# [101]	validation_0-logloss:0.53777
# [102]	validation_0-logloss:0.53757
# [103]	validation_0-logloss:0.53770
# [104]	validation_0-logloss:0.53729
# [105]	validation_0-logloss:0.53758
# [106]	validation_0-logloss:0.53707
# [107]	validation_0-logloss:0.53707
# [108]	validation_0-logloss:0.53781
# [109]	validation_0-logloss:0.53770
# [110]	validation_0-logloss:0.53711
# [111]	validation_0-logloss:0.53789
# [112]	validation_0-logloss:0.53783
# [113]	validation_0-logloss:0.53787
# [114]	validation_0-logloss:0.53784
# [115]	validation_0-logloss:0.53875
# [116]	validation_0-logloss:0.53866
# [117]	validation_0-logloss:0.53792
# [118]	validation_0-logloss:0.53784
# [119]	validation_0-logloss:0.53825
# [120]	validation_0-logloss:0.53827
# [121]	validation_0-logloss:0.53776
# [122]	validation_0-logloss:0.53724
# [123]	validation_0-logloss:0.53711
# [124]	validation_0-logloss:0.53721
# [125]	validation_0-logloss:0.53779
# [126]	validation_0-logloss:0.53796
# [127]	validation_0-logloss:0.53843
# [128]	validation_0-logloss:0.53795
# [129]	validation_0-logloss:0.53802
# [130]	validation_0-logloss:0.53876
# [131]	validation_0-logloss:0.53847
# [132]	validation_0-logloss:0.53893
# [133]	validation_0-logloss:0.53868
# [134]	validation_0-logloss:0.53886
# [135]	validation_0-logloss:0.53869
# [136]	validation_0-logloss:0.53866
# [137]	validation_0-logloss:0.53872
# [138]	validation_0-logloss:0.53865
# [139]	validation_0-logloss:0.53875
# [140]	validation_0-logloss:0.53904
# [141]	validation_0-logloss:0.53869
# [142]	validation_0-logloss:0.53925
# [143]	validation_0-logloss:0.53886
# [144]	validation_0-logloss:0.53944
# [145]	validation_0-logloss:0.53956
# [146]	validation_0-logloss:0.53943
# [147]	validation_0-logloss:0.53950
# [148]	validation_0-logloss:0.53956
# [149]	validation_0-logloss:0.53938
# [150]	validation_0-logloss:0.53921
# [151]	validation_0-logloss:0.53971
# [152]	validation_0-logloss:0.53951
# [153]	validation_0-logloss:0.54018
# [154]	validation_0-logloss:0.54030
# [155]	validation_0-logloss:0.54039
# [156]	validation_0-logloss:0.54052
# [157]	validation_0-logloss:0.54079
# [158]	validation_0-logloss:0.54049
# [159]	validation_0-logloss:0.54068
# [160]	validation_0-logloss:0.54079
# [161]	validation_0-logloss:0.54074
# [162]	validation_0-logloss:0.54122
# [163]	validation_0-logloss:0.54132
# [164]	validation_0-logloss:0.54134
# [165]	validation_0-logloss:0.54153
# [166]	validation_0-logloss:0.54114
# [167]	validation_0-logloss:0.54089
# [168]	validation_0-logloss:0.54129
# [169]	validation_0-logloss:0.54146
# [170]	validation_0-logloss:0.54179
# [171]	validation_0-logloss:0.54144
# [172]	validation_0-logloss:0.54205
# [173]	validation_0-logloss:0.54228
# [174]	validation_0-logloss:0.54231
# [175]	validation_0-logloss:0.54247
# [176]	validation_0-logloss:0.54257
# [177]	validation_0-logloss:0.54266
# [178]	validation_0-logloss:0.54257
# [179]	validation_0-logloss:0.54285
# [180]	validation_0-logloss:0.54227
# [181]	validation_0-logloss:0.54247
# [182]	validation_0-logloss:0.54227
# [183]	validation_0-logloss:0.54256
# [184]	validation_0-logloss:0.54242
# [185]	validation_0-logloss:0.54273
# [186]	validation_0-logloss:0.54284
# [187]	validation_0-logloss:0.54297
# [188]	validation_0-logloss:0.54287
# [189]	validation_0-logloss:0.54332
# [190]	validation_0-logloss:0.54339
# [191]	validation_0-logloss:0.54369
# [192]	validation_0-logloss:0.54356
# [193]	validation_0-logloss:0.54381
# [194]	validation_0-logloss:0.54403
# [195]	validation_0-logloss:0.54397
# [196]	validation_0-logloss:0.54370
# [197]	validation_0-logloss:0.54382
# [198]	validation_0-logloss:0.54392
# [199]	validation_0-logloss:0.54382
# [200]	validation_0-logloss:0.54376
# [201]	validation_0-logloss:0.54426
# [202]	validation_0-logloss:0.54438
# [203]	validation_0-logloss:0.54418
# [204]	validation_0-logloss:0.54439
# [205]	validation_0-logloss:0.54525
# [206]	validation_0-logloss:0.54521
# [207]	validation_0-logloss:0.54507
# [208]	validation_0-logloss:0.54534
# [209]	validation_0-logloss:0.54542
# [210]	validation_0-logloss:0.54530
# [211]	validation_0-logloss:0.54516
# [212]	validation_0-logloss:0.54511
# [213]	validation_0-logloss:0.54512
# [214]	validation_0-logloss:0.54525
# [215]	validation_0-logloss:0.54485
# [216]	validation_0-logloss:0.54488
# [217]	validation_0-logloss:0.54502
# [218]	validation_0-logloss:0.54465
# [219]	validation_0-logloss:0.54449
# [220]	validation_0-logloss:0.54449
# [221]	validation_0-logloss:0.54427
# [222]	validation_0-logloss:0.54397
# [223]	validation_0-logloss:0.54380
# [224]	validation_0-logloss:0.54385
# [225]	validation_0-logloss:0.54383
# [226]	validation_0-logloss:0.54420
# [227]	validation_0-logloss:0.54421
# [228]	validation_0-logloss:0.54394
# [229]	validation_0-logloss:0.54386
# [230]	validation_0-logloss:0.54375
# [231]	validation_0-logloss:0.54367
# [232]	validation_0-logloss:0.54351
# [233]	validation_0-logloss:0.54351
# [234]	validation_0-logloss:0.54479
# [235]	validation_0-logloss:0.54506
# [236]	validation_0-logloss:0.54503
# [237]	validation_0-logloss:0.54514
# [238]	validation_0-logloss:0.54544
# [239]	validation_0-logloss:0.54578
# [240]	validation_0-logloss:0.54599
# [241]	validation_0-logloss:0.54646
# [242]	validation_0-logloss:0.54663
# [243]	validation_0-logloss:0.54662
# [244]	validation_0-logloss:0.54688
# [245]	validation_0-logloss:0.54686
# [246]	validation_0-logloss:0.54702
# [247]	validation_0-logloss:0.54694
# [248]	validation_0-logloss:0.54722
# [249]	validation_0-logloss:0.54717
# [250]	validation_0-logloss:0.54744
# [251]	validation_0-logloss:0.54712
# [252]	validation_0-logloss:0.54742
# [253]	validation_0-logloss:0.54742
# [254]	validation_0-logloss:0.54733
# [255]	validation_0-logloss:0.54721
# [256]	validation_0-logloss:0.54766
# [257]	validation_0-logloss:0.54760
# [258]	validation_0-logloss:0.54778
# [259]	validation_0-logloss:0.54771
# [260]	validation_0-logloss:0.54803
# [261]	validation_0-logloss:0.54840
# [262]	validation_0-logloss:0.54884
# [263]	validation_0-logloss:0.54885
# [264]	validation_0-logloss:0.54914
# [265]	validation_0-logloss:0.54941
# [266]	validation_0-logloss:0.54936
# [267]	validation_0-logloss:0.54941
# [268]	validation_0-logloss:0.54921
# [269]	validation_0-logloss:0.54924
# [270]	validation_0-logloss:0.54938
# [271]	validation_0-logloss:0.54915
# [272]	validation_0-logloss:0.54977
# [273]	validation_0-logloss:0.55016
# [274]	validation_0-logloss:0.55082
# [275]	validation_0-logloss:0.55074
# [276]	validation_0-logloss:0.55081
# [277]	validation_0-logloss:0.55123
# [278]	validation_0-logloss:0.55100
# [279]	validation_0-logloss:0.55076
# [280]	validation_0-logloss:0.55067
# [281]	validation_0-logloss:0.55075
# [282]	validation_0-logloss:0.55082
# [283]	validation_0-logloss:0.55092
# [284]	validation_0-logloss:0.55123
# [285]	validation_0-logloss:0.55122
# [286]	validation_0-logloss:0.55130
# [287]	validation_0-logloss:0.55196
# [288]	validation_0-logloss:0.55214
# [289]	validation_0-logloss:0.55238
# [290]	validation_0-logloss:0.55216
# [291]	validation_0-logloss:0.55202
# [292]	validation_0-logloss:0.55218
# [293]	validation_0-logloss:0.55246
# [294]	validation_0-logloss:0.55236
# [295]	validation_0-logloss:0.55262
# [296]	validation_0-logloss:0.55265
# [297]	validation_0-logloss:0.55282
# [298]	validation_0-logloss:0.55260
# [299]	validation_0-logloss:0.55286
# [300]	validation_0-logloss:0.55283
# [301]	validation_0-logloss:0.55311
# [302]	validation_0-logloss:0.55335
# [303]	validation_0-logloss:0.55335
# [304]	validation_0-logloss:0.55321
# [305]	validation_0-logloss:0.55339
# [306]	validation_0-logloss:0.55349
# [307]	validation_0-logloss:0.55321
# [308]	validation_0-logloss:0.55338
# [309]	validation_0-logloss:0.55391
# [310]	validation_0-logloss:0.55422
# [311]	validation_0-logloss:0.55425
# [312]	validation_0-logloss:0.55427
# [313]	validation_0-logloss:0.55452
# [314]	validation_0-logloss:0.55414
# [315]	validation_0-logloss:0.55424
# [316]	validation_0-logloss:0.55429
# [317]	validation_0-logloss:0.55444
# [318]	validation_0-logloss:0.55439
# [319]	validation_0-logloss:0.55473
# [320]	validation_0-logloss:0.55476
# [321]	validation_0-logloss:0.55501
# [322]	validation_0-logloss:0.55540
# [323]	validation_0-logloss:0.55600
# [324]	validation_0-logloss:0.55651
# [325]	validation_0-logloss:0.55677
# [326]	validation_0-logloss:0.55677
# [327]	validation_0-logloss:0.55665
# [328]	validation_0-logloss:0.55720
# [329]	validation_0-logloss:0.55717
# [330]	validation_0-logloss:0.55736
# [331]	validation_0-logloss:0.55732
# [332]	validation_0-logloss:0.55727
# [333]	validation_0-logloss:0.55788
# [334]	validation_0-logloss:0.55806
# [335]	validation_0-logloss:0.55846
# [336]	validation_0-logloss:0.55851
# [337]	validation_0-logloss:0.55933
# [338]	validation_0-logloss:0.55906
# [339]	validation_0-logloss:0.55891
# [340]	validation_0-logloss:0.55904
# [341]	validation_0-logloss:0.55927
# [342]	validation_0-logloss:0.55932
# [343]	validation_0-logloss:0.55958
# [344]	validation_0-logloss:0.55960
# [345]	validation_0-logloss:0.56016
# [346]	validation_0-logloss:0.56052
# [347]	validation_0-logloss:0.56048
# [348]	validation_0-logloss:0.56057
# [349]	validation_0-logloss:0.56069
# [350]	validation_0-logloss:0.56060
# [351]	validation_0-logloss:0.56061
# [352]	validation_0-logloss:0.56070
# [353]	validation_0-logloss:0.56069
# [354]	validation_0-logloss:0.56087
# [355]	validation_0-logloss:0.56090
# [356]	validation_0-logloss:0.56091
# [357]	validation_0-logloss:0.56132
# [358]	validation_0-logloss:0.56125
# [359]	validation_0-logloss:0.56131
# [360]	validation_0-logloss:0.56128
# [361]	validation_0-logloss:0.56128
# [362]	validation_0-logloss:0.56118
# [363]	validation_0-logloss:0.56165
# [364]	validation_0-logloss:0.56159
# [365]	validation_0-logloss:0.56162
# [366]	validation_0-logloss:0.56173
# [367]	validation_0-logloss:0.56189
# [368]	validation_0-logloss:0.56191
# [369]	validation_0-logloss:0.56219
# [370]	validation_0-logloss:0.56238
# [371]	validation_0-logloss:0.56224
# [372]	validation_0-logloss:0.56235
# [373]	validation_0-logloss:0.56226
# [374]	validation_0-logloss:0.56269
# [375]	validation_0-logloss:0.56276
# [376]	validation_0-logloss:0.56270
# [377]	validation_0-logloss:0.56259
# [378]	validation_0-logloss:0.56250
# [379]	validation_0-logloss:0.56248
# [380]	validation_0-logloss:0.56328
# [381]	validation_0-logloss:0.56333
# [382]	validation_0-logloss:0.56376
# [383]	validation_0-logloss:0.56396
# [384]	validation_0-logloss:0.56419
# [385]	validation_0-logloss:0.56415
# [386]	validation_0-logloss:0.56478
# [387]	validation_0-logloss:0.56490
# [388]	validation_0-logloss:0.56532
# [389]	validation_0-logloss:0.56542
# [390]	validation_0-logloss:0.56520
# [391]	validation_0-logloss:0.56547
# [392]	validation_0-logloss:0.56597
# [393]	validation_0-logloss:0.56616
# [394]	validation_0-logloss:0.56668
# [395]	validation_0-logloss:0.56677
# [396]	validation_0-logloss:0.56715
# [397]	validation_0-logloss:0.56703
# [398]	validation_0-logloss:0.56686
# [399]	validation_0-logloss:0.56729
# [400]	validation_0-logloss:0.56720
# [401]	validation_0-logloss:0.56727
# [402]	validation_0-logloss:0.56753
# [403]	validation_0-logloss:0.56763
# [404]	validation_0-logloss:0.56774
# [405]	validation_0-logloss:0.56760
# [406]	validation_0-logloss:0.56795
# [407]	validation_0-logloss:0.56801
# [408]	validation_0-logloss:0.56820
# [409]	validation_0-logloss:0.56803
# [410]	validation_0-logloss:0.56831
# [411]	validation_0-logloss:0.56840
# [412]	validation_0-logloss:0.56882
# [413]	validation_0-logloss:0.56894
# [414]	validation_0-logloss:0.56901
# [415]	validation_0-logloss:0.56922
# [416]	validation_0-logloss:0.56958
# [417]	validation_0-logloss:0.56952
# [418]	validation_0-logloss:0.56925
# [419]	validation_0-logloss:0.56989
# [420]	validation_0-logloss:0.57012
# [421]	validation_0-logloss:0.57033
# [422]	validation_0-logloss:0.57055
# [423]	validation_0-logloss:0.57092
# [424]	validation_0-logloss:0.57095
# [425]	validation_0-logloss:0.57123
# [426]	validation_0-logloss:0.57131
# [427]	validation_0-logloss:0.57151
# [428]	validation_0-logloss:0.57159
# [429]	validation_0-logloss:0.57159
# [430]	validation_0-logloss:0.57191
# [431]	validation_0-logloss:0.57204
# [432]	validation_0-logloss:0.57222
# [433]	validation_0-logloss:0.57237
# [434]	validation_0-logloss:0.57247
# [435]	validation_0-logloss:0.57284
# [436]	validation_0-logloss:0.57300
# [437]	validation_0-logloss:0.57300
# [438]	validation_0-logloss:0.57288
# [439]	validation_0-logloss:0.57308
# [440]	validation_0-logloss:0.57329
# [441]	validation_0-logloss:0.57351
# [442]	validation_0-logloss:0.57355
# [443]	validation_0-logloss:0.57406
# [444]	validation_0-logloss:0.57454
# [445]	validation_0-logloss:0.57484
# [446]	validation_0-logloss:0.57524
# [447]	validation_0-logloss:0.57526
# [448]	validation_0-logloss:0.57512
# [449]	validation_0-logloss:0.57560
# [450]	validation_0-logloss:0.57604
# [451]	validation_0-logloss:0.57646
# [452]	validation_0-logloss:0.57652
# [453]	validation_0-logloss:0.57693
# [454]	validation_0-logloss:0.57699
# [455]	validation_0-logloss:0.57703
# [456]	validation_0-logloss:0.57718
# [457]	validation_0-logloss:0.57731
# [458]	validation_0-logloss:0.57741
# [459]	validation_0-logloss:0.57783
# [460]	validation_0-logloss:0.57789
# [461]	validation_0-logloss:0.57836
# [462]	validation_0-logloss:0.57855
# [463]	validation_0-logloss:0.57891
# [464]	validation_0-logloss:0.57902
# [465]	validation_0-logloss:0.57914
# [466]	validation_0-logloss:0.57900
# [467]	validation_0-logloss:0.57898
# [468]	validation_0-logloss:0.57903
# [469]	validation_0-logloss:0.57922
# [470]	validation_0-logloss:0.57943
# [471]	validation_0-logloss:0.57991
# [472]	validation_0-logloss:0.57990
# [473]	validation_0-logloss:0.57984
# [474]	validation_0-logloss:0.57996
# [475]	validation_0-logloss:0.58027
# [476]	validation_0-logloss:0.58016
# [477]	validation_0-logloss:0.58022
# [478]	validation_0-logloss:0.58036
# [479]	validation_0-logloss:0.58025
# [480]	validation_0-logloss:0.58030
# [481]	validation_0-logloss:0.58028
# [482]	validation_0-logloss:0.58024
# [483]	validation_0-logloss:0.58032
# [484]	validation_0-logloss:0.58057
# [485]	validation_0-logloss:0.58078
# [486]	validation_0-logloss:0.58121
# [487]	validation_0-logloss:0.58138
# [488]	validation_0-logloss:0.58157
# [489]	validation_0-logloss:0.58192
# [490]	validation_0-logloss:0.58181
# [491]	validation_0-logloss:0.58220
# [492]	validation_0-logloss:0.58248
# [493]	validation_0-logloss:0.58244
# [494]	validation_0-logloss:0.58232
# [495]	validation_0-logloss:0.58232
# [496]	validation_0-logloss:0.58285
# [497]	validation_0-logloss:0.58310
# [498]	validation_0-logloss:0.58347
# [499]	validation_0-logloss:0.58376
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# Predict probabilities
y_val_pred_proba = xgb_model.predict_proba(X_val)[:, 1]  # probability of completion

# Optional: predict 0/1
y_val_pred = xgb_model.predict(X_val)

# Metrics
auc = roc_auc_score(y_val, y_val_pred_proba)
accuracy = accuracy_score(y_val, y_val_pred)
logloss = log_loss(y_val, y_val_pred_proba)

print(f"Validation AUC: {auc:.4f}")
print(f"Validation Accuracy: {accuracy:.4f}")
print(f"Validation Log Loss: {logloss:.4f}")
# Out:
# Validation AUC: 0.7832
# Validation Accuracy: 0.7221
# Validation Log Loss: 0.5838

# %%
# Save Model
joblib.dump(xgb_model, "completion_prob_model_xgb.pkl")
# Out:
# ['completion_prob_model_xgb.pkl']

# %%
# Create Feature Importance Plot
import matplotlib.pyplot as plt
import seaborn as sns

# Get feature importance
importance = xgb_model.feature_importances_
fi_df = pd.DataFrame({'feature': feature_cols, 'importance': importance})
fi_df = fi_df.sort_values('importance', ascending=False)

# Plot top 20 features
plt.figure(figsize=(10,6))
sns.barplot(data=fi_df.head(20), x='importance', y='feature')
plt.title("Top 20 Feature Importances")
plt.show()

# %% [markdown]
# ### Augment Data with Model Results

# %%
# Feature List
cat_cols = ['route_group', 'route_of_targeted_receiver']

num_cols = [
    'flight_normalized_time', 'pass_length',
    'def_close1_dist', 'def_close2_dist', 'def_close3_dist', 'def_close4_dist',
    'tgt_rec_closing_speed_ball', 'def_close1_closing_speed_ball', 'def_close2_closing_speed_ball',
    'def_close3_closing_speed_ball', 'def_close4_closing_speed_ball', 'def_close1_closing_speed_ball_adv',
    'def_close2_closing_speed_ball_adv', 'def_close3_closing_speed_ball_adv', 'def_close4_closing_speed_ball_adv',
    'def_close1_momentum_adv', 'def_close2_momentum_adv', 'def_close3_momentum_adv', 'def_close4_momentum_adv',
    'def_close1_closing_speed_rec', 'def_close2_closing_speed_rec', 'def_close3_closing_speed_rec', 'def_close4_closing_speed_rec',
    'mean_separation_closest_3_defs', 'min_ball_dist_all_def', 'ball_dist_advantage',
    'def_close1_angle_rec_deg', 'def_close2_angle_rec_deg', 'def_close3_angle_rec_deg', 'def_close4_angle_rec_deg',
    'def_close1_angle_ball_deg', 'def_close2_angle_ball_deg', 'def_close3_angle_ball_deg', 'def_close4_angle_ball_deg',
    'tgt_rec_t_to_ball', 'min_t_def_to_ball', 'min_t_def_minus_t_rec', 'tgt_rec_ball_facing_angle',
    'tgt_rec_sideline_dist', 'tgt_rec_turn_angle_smoothed', 'crowdedness', 'tgt_rec_a_toward_ball',
    'closest_2_def_angle_diff'
]

model_cols = cat_cols + num_cols

# %%
data_adv = pd.read_csv("data_adv.csv")

# %%
def augment_completion_prob(df, model_cols, xgb_model):
    df_aug = df.copy()

    df_aug['completion_prob'] = np.nan

    after_release_mask = df['to_release'] == 'after'
    frames_after_release = df_aug[after_release_mask]

    for (gid, pid), play_data in frames_after_release.groupby(['game_id', 'play_id']):
        play_data = play_data.sort_values('frame_global', ascending=True)

        X_play = play_data[model_cols].copy()

        for col in ['route_group', 'route_of_targeted_receiver']:
            if col in X_play.columns:
                X_play[col] = X_play[col].astype('category').cat.codes

        # Predict probabilities
        probs = xgb_model.predict_proba(X_play)[:, 1]

        # Assign back to the dataframe
        df_aug.loc[play_data.index, 'completion_prob'] = probs

        # Calculate Area Under Curve (AUC) slices relative to first frame of play
        baseline_prob = probs[0]
        width = 1 / len(probs)
        height = probs - baseline_prob
        auc_slices = width * height
        df_aug.loc[play_data.index, 'auc_slice'] = auc_slices

    return df_aug

# %%
data_with_probs = augment_completion_prob(data_adv, model_cols, xgb_model)

# %%
data_with_probs.to_csv("data_with_probs.csv", index=False)
